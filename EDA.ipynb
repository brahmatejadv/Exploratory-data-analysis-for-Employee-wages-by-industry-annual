# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1=pd.read_csv("C:\\Users\\BRAHMA TEJA\\Desktop\\Book2.csv")
data1
# Out:
#        REF_DATE                        GEO        DGUID  \
# 0          1997  Newfoundland and Labrador  2016A000210
# 1          1997  Newfoundland and Labrador  2016A000210
# 2          1997  Newfoundland and Labrador  2016A000210
# 3          1997  Newfoundland and Labrador  2016A000210
# 4          1997  Newfoundland and Labrador  2016A000210
# ...         ...                        ...          ...
# 69115      2020           British Columbia  2016A000259
# 69116      2020           British Columbia  2016A000259
# 69117      2020           British Columbia  2016A000259
# 69118      2020           British Columbia  2016A000259
# 69119      2020           British Columbia  2016A000259
#
#                           Wages         Type of work  \
# 0      Average hourly wage rate  Full-time employees
# 1      Average hourly wage rate  Full-time employees
# 2      Average hourly wage rate  Full-time employees
# 3      Average hourly wage rate  Full-time employees
# ...

# %%
data.shape
# Out:
# (902880, 19)

# %%
data.head
# Out:
# <bound method NDFrame.head of         REF_DATE               GEO           DGUID  \
# 0           1997            Canada  2016A000011124
# 1           1997            Canada  2016A000011124
# 2           1997            Canada  2016A000011124
# 3           1997            Canada  2016A000011124
# 4           1997            Canada  2016A000011124
# ...          ...               ...             ...
# 902875      2020  British Columbia     2016A000259
# 902876      2020  British Columbia     2016A000259
# 902877      2020  British Columbia     2016A000259
# 902878      2020  British Columbia     2016A000259
# 902879      2020  British Columbia     2016A000259
#
#                              Wages                        Type of work  \
# 0       Total employees, all wages  Both full- and part-time employees
# 1       Total employees, all wages  Both full- and part-time employees
# 2       Total employees, all wages  Both full- and part-time employees
# ...

# %%
data.tail
# Out:
# <bound method NDFrame.tail of         REF_DATE               GEO           DGUID  \
# 0           1997            Canada  2016A000011124
# 1           1997            Canada  2016A000011124
# 2           1997            Canada  2016A000011124
# 3           1997            Canada  2016A000011124
# 4           1997            Canada  2016A000011124
# ...          ...               ...             ...
# 902875      2020  British Columbia     2016A000259
# 902876      2020  British Columbia     2016A000259
# 902877      2020  British Columbia     2016A000259
# 902878      2020  British Columbia     2016A000259
# 902879      2020  British Columbia     2016A000259
#
#                              Wages                        Type of work  \
# 0       Total employees, all wages  Both full- and part-time employees
# 1       Total employees, all wages  Both full- and part-time employees
# 2       Total employees, all wages  Both full- and part-time employees
# ...

# %%
data.info
# Out:
# <bound method DataFrame.info of         REF_DATE               GEO           DGUID  \
# 0           1997            Canada  2016A000011124
# 1           1997            Canada  2016A000011124
# 2           1997            Canada  2016A000011124
# 3           1997            Canada  2016A000011124
# 4           1997            Canada  2016A000011124
# ...          ...               ...             ...
# 902875      2020  British Columbia     2016A000259
# 902876      2020  British Columbia     2016A000259
# 902877      2020  British Columbia     2016A000259
# 902878      2020  British Columbia     2016A000259
# 902879      2020  British Columbia     2016A000259
#
#                              Wages                        Type of work  \
# 0       Total employees, all wages  Both full- and part-time employees
# 1       Total employees, all wages  Both full- and part-time employees
# 2       Total employees, all wages  Both full- and part-time employees
# ...

# %%
data.describe
# Out:
# <bound method NDFrame.describe of         REF_DATE               GEO           DGUID  \
# 0           1997            Canada  2016A000011124
# 1           1997            Canada  2016A000011124
# 2           1997            Canada  2016A000011124
# 3           1997            Canada  2016A000011124
# 4           1997            Canada  2016A000011124
# ...          ...               ...             ...
# 902875      2020  British Columbia     2016A000259
# 902876      2020  British Columbia     2016A000259
# 902877      2020  British Columbia     2016A000259
# 902878      2020  British Columbia     2016A000259
# 902879      2020  British Columbia     2016A000259
#
#                              Wages                        Type of work  \
# 0       Total employees, all wages  Both full- and part-time employees
# 1       Total employees, all wages  Both full- and part-time employees
# 2       Total employees, all wages  Both full- and part-time employees
# ...

# %%
data.isnull().sum()
# Out:
# REF_DATE                                                      0
# GEO                                                           0
# DGUID                                                         0
# Wages                                                         0
# Type of work                                                  0
# North American Industry Classification System (NAICS)         0
# Sex                                                           0
# Age group                                                     0
# UOM                                                           0
# UOM_ID                                                        0
# SCALAR_FACTOR                                                 0
# SCALAR_ID                                                     0
# VECTOR                                                        0
# COORDINATE                                                    0
# VALUE                                                    156410
# ...

# %%
data.duplicated().sum()
# Out:
# 0

# %%
gapminder_data = data1[data1['GEO']!='Canada']

# %%
gapminder_data
# Out:
#        REF_DATE                        GEO        DGUID  \
# 0          1997  Newfoundland and Labrador  2016A000210
# 1          1997  Newfoundland and Labrador  2016A000210
# 2          1997  Newfoundland and Labrador  2016A000210
# 3          1997  Newfoundland and Labrador  2016A000210
# 4          1997  Newfoundland and Labrador  2016A000210
# ...         ...                        ...          ...
# 69115      2020           British Columbia  2016A000259
# 69116      2020           British Columbia  2016A000259
# 69117      2020           British Columbia  2016A000259
# 69118      2020           British Columbia  2016A000259
# 69119      2020           British Columbia  2016A000259
#
#                           Wages         Type of work  \
# 0      Average hourly wage rate  Full-time employees
# 1      Average hourly wage rate  Full-time employees
# 2      Average hourly wage rate  Full-time employees
# 3      Average hourly wage rate  Full-time employees
# ...

# %%
gapminder_data.boxplot(column=['VALUE'],by='Type of work')
# Out:
# <AxesSubplot:title={'center':'VALUE'}, xlabel='Type of work'>
